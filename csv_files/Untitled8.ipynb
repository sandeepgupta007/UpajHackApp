# %%
from sklearn.linear_model import LinearRegression

# %%
import pandas as pd

# %%
data = pd.read_csv('feeder.csv')

# %%
data.head()
# Out:
#    state  district  year  season  crop    area  production    JAN   FEB  \
# 0     31         0  2000       3    90  1254.0       2000.0  53.0  59.0
# 1     31         0  2000       3    43     2.0          1.0  53.0  59.0
# 2     31         0  2000       3     2   102.0        321.0  53.0  59.0
# 3     31         0  2000       2   107   176.0        641.0  53.0  59.0
# 4     31         0  2000       2   120   720.0        165.0  53.0  59.0
#
#      MAR         ...            MAY    JUN    JUL    AUG    SEP    OCT    NOV  \
# 0  171.3         ...          422.8  357.0  176.3  460.8  250.1  321.2  158.3
# 1  171.3         ...          422.8  357.0  176.3  460.8  250.1  321.2  158.3
# 2  171.3         ...          422.8  357.0  176.3  460.8  250.1  321.2  158.3
# 3  171.3         ...          422.8  357.0  176.3  460.8  250.1  321.2  158.3
# 4  171.3         ...          422.8  357.0  176.3  460.8  250.1  321.2  158.3
#
#      DEC  ANNUAL  production_by_area
# ...

# %%
copy = data.head()

# %%
import seaborn as sb

# %%
sb.pairplot(copy)

# %%
data.head()
# Out:
#    state  district  year  season  crop    area  production    JAN   FEB  \
# 0     31         0  2000       3    90  1254.0       2000.0  53.0  59.0
# 1     31         0  2000       3    43     2.0          1.0  53.0  59.0
# 2     31         0  2000       3     2   102.0        321.0  53.0  59.0
# 3     31         0  2000       2   107   176.0        641.0  53.0  59.0
# 4     31         0  2000       2   120   720.0        165.0  53.0  59.0
#
#      MAR         ...            MAY    JUN    JUL    AUG    SEP    OCT    NOV  \
# 0  171.3         ...          422.8  357.0  176.3  460.8  250.1  321.2  158.3
# 1  171.3         ...          422.8  357.0  176.3  460.8  250.1  321.2  158.3
# 2  171.3         ...          422.8  357.0  176.3  460.8  250.1  321.2  158.3
# 3  171.3         ...          422.8  357.0  176.3  460.8  250.1  321.2  158.3
# 4  171.3         ...          422.8  357.0  176.3  460.8  250.1  321.2  158.3
#
#      DEC  ANNUAL  production_by_area
# ...

# %%
data.head()
# Out:
#    state  district  year  season  crop    area  production    JAN   FEB  \
# 0     31         0  2000       3    90  1254.0       2000.0  53.0  59.0
# 1     31         0  2000       3    43     2.0          1.0  53.0  59.0
# 2     31         0  2000       3     2   102.0        321.0  53.0  59.0
# 3     31         0  2000       2   107   176.0        641.0  53.0  59.0
# 4     31         0  2000       2   120   720.0        165.0  53.0  59.0
#
#      MAR         ...            MAY    JUN    JUL    AUG    SEP    OCT    NOV  \
# 0  171.3         ...          422.8  357.0  176.3  460.8  250.1  321.2  158.3
# 1  171.3         ...          422.8  357.0  176.3  460.8  250.1  321.2  158.3
# 2  171.3         ...          422.8  357.0  176.3  460.8  250.1  321.2  158.3
# 3  171.3         ...          422.8  357.0  176.3  460.8  250.1  321.2  158.3
# 4  171.3         ...          422.8  357.0  176.3  460.8  250.1  321.2  158.3
#
#      DEC  ANNUAL  production_by_area
# ...

# %%
data.keys()
# Out:
# Index(['state', 'district', 'year', 'season', 'crop', 'area', 'production ',
#        'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT',
#        'NOV', 'DEC', 'ANNUAL', 'production_by_area'],
#       dtype='object')

# %%
data.shape
# Out:
# (212582, 21)

# %%
data.features_name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-2f5e0e8b668e> in <module>()
# ----> 1 data.features_name
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'features_name'

# %%
print(data.DESCR)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-f64d1210d0a4> in <module>()
# ----> 1 print(data.DESCR)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'DESCR'

# %%
d = data.filter(['year', 'crop', 'production_by_area'], axis=1)

# %%
d.head()
# Out:
#    year  crop  production_by_area
# 0  2000    90            1.594896
# 1  2000    43            0.500000
# 2  2000     2            3.147059
# 3  2000   107            3.642045
# 4  2000   120            0.229167

# %%
df = pd.DataFrame(d)

# %%
df.head()
# Out:
#    state  year  ANNUAL  production_by_area
# 0     31  2000  2763.2            1.594896
# 1     31  2000  2763.2            0.500000
# 2     31  2000  2763.2            3.147059
# 3     31  2000  2763.2            3.642045
# 4     31  2000  2763.2            0.229167

# %%
from sklearn.linear_model import LinearRegression

# %%
X = df.drop('production_by_area', axis = 1)

# %%
X.head()
# Out:
#    state  year  ANNUAL
# 0     31  2000  2763.2
# 1     31  2000  2763.2
# 2     31  2000  2763.2
# 3     31  2000  2763.2
# 4     31  2000  2763.2

# %%
regression = LinearRegression()

# %%
regression
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
df.head()
# Out:
#    state  year  ANNUAL  production_by_area
# 0     31  2000  2763.2            1.594896
# 1     31  2000  2763.2            0.500000
# 2     31  2000  2763.2            3.147059
# 3     31  2000  2763.2            3.642045
# 4     31  2000  2763.2            0.229167

# %%
label = df['production_by_area']
label
# Out:
# 0            1.594896
# 1            0.500000
# 2            3.147059
# 3            3.642045
# 4            0.229167
# 5         3583.223250
# 6            2.777778
# 7            2.000000
# 8            3.000000
# 9            4.225000
# 10           1.643541
# 11           0.500000
# 12           3.614458
# 13           0.267038
# 14        3542.056075
# 15           2.173913
# 16           1.000000
# 17           3.000000
# 18           2.700000
# 19           1.655803
# 20           6.000000
# 21           0.214286
# 22           0.289291
# 23        3700.109649
# 24           0.069734
# 25           2.811839
# 26           8.000000
# 27           1.734038
# 28           1.209358
# 29           6.627820
#              ...
# 212552       0.387755
# 212553      12.987421
# 212554       0.552486
# 212555       0.875000
# 212556       0.362745
# 212557       0.493671
# 212558       4.251462
# 212559       0.388889
# 212560       0.913043
# 212561       0.286000
# ...

# %%
regression.fit(X, df['production_by_area'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-47cb7fd3c299> in <module>()
# ----> 1 regression.fit(X, df['production_by_area'])
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...

# %%
import numpy as np

# %%
df.head()
# Out:
#    state  year  ANNUAL  production_by_area
# 0     31  2000  2763.2            1.594896
# 1     31  2000  2763.2            0.500000
# 2     31  2000  2763.2            3.147059
# 3     31  2000  2763.2            3.642045
# 4     31  2000  2763.2            0.229167

# %%
df.fillna(df.mean()).head()
# Out:
#    state  year  ANNUAL  production_by_area
# 0     31  2000  2763.2            1.594896
# 1     31  2000  2763.2            0.500000
# 2     31  2000  2763.2            3.147059
# 3     31  2000  2763.2            3.642045
# 4     31  2000  2763.2            0.229167

# %%
regression.fit(X, df['production_by_area'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-47cb7fd3c299> in <module>()
# ----> 1 regression.fit(X, df['production_by_area'])
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...

# %%
np.nan_to_num(X)
# Out:
# array([[  31. , 2000. , 2763.2],
#        [  31. , 2000. , 2763.2],
#        [  31. , 2000. , 2763.2],
#        ...,
#        [  19. , 2014. , 1261.4],
#        [  19. , 2014. , 1261.4],
#        [  19. , 2014. , 1261.4]])

# %%
X.head()
# Out:
#    state  year  ANNUAL
# 0     31  2000  2763.2
# 1     31  2000  2763.2
# 2     31  2000  2763.2
# 3     31  2000  2763.2
# 4     31  2000  2763.2

# %%
X = X.fillna(X.mean())

# %%
label.head()
# Out:
# 0    1.594896
# 1    0.500000
# 2    3.147059
# 3    3.642045
# 4    0.229167
# Name: production_by_area, dtype: float64

# %%
np.isnan(X).any()
# Out:
# state     False
# year      False
# ANNUAL    False
# dtype: bool

# %%
label.fillna(label.mean())
# Out:
# 0            1.594896
# 1            0.500000
# 2            3.147059
# 3            3.642045
# 4            0.229167
# 5         3583.223250
# 6            2.777778
# 7            2.000000
# 8            3.000000
# 9            4.225000
# 10           1.643541
# 11           0.500000
# 12           3.614458
# 13           0.267038
# 14        3542.056075
# 15           2.173913
# 16           1.000000
# 17           3.000000
# 18           2.700000
# 19           1.655803
# 20           6.000000
# 21           0.214286
# 22           0.289291
# 23        3700.109649
# 24           0.069734
# 25           2.811839
# 26           8.000000
# 27           1.734038
# 28           1.209358
# 29           6.627820
#              ...
# 212552       0.387755
# 212553      12.987421
# 212554       0.552486
# 212555       0.875000
# 212556       0.362745
# 212557       0.493671
# 212558       4.251462
# 212559       0.388889
# 212560       0.913043
# 212561       0.286000
# ...

# %%
regression.fit(X, label)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-3a64ef887183> in <module>()
# ----> 1 regression.fit(X, label)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...

# %%
np.where(label.values >= np.finfo(np.float64).max)
# Out:
# /home/reaper/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in greater_equal
#   """Entry point for launching an IPython kernel.
# (array([], dtype=int64),)

# %%
label.dtype
# Out:
# dtype('float64')

# %%
X.dtypes
# Out:
# state       int64
# year        int64
# ANNUAL    float64
# dtype: object

# %%
np.isnan(data).any()
# Out:
# state                 False
# district              False
# year                  False
# season                False
# crop                  False
# area                  False
# production             True
# JAN                    True
# FEB                    True
# MAR                    True
# APR                    True
# MAY                    True
# JUN                    True
# JUL                    True
# AUG                    True
# SEP                    True
# OCT                    True
# NOV                    True
# DEC                    True
# ANNUAL                 True
# production_by_area     True
# dtype: bool

# %%
X['ANNUAL'] = X['ANNUAL'].fillna(X['ANNUAL'].mean())

# %%
X.drop(X['Annual'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-125-80e09d48f220> in <module>()
# ----> 1 X.drop(X['Annual'], axis = 1)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# -> 3694                                            errors=errors)
#    3695
#    3696     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3106         for axis, labels in axes.items():
#    3107             if labels is not None:
# ...

# %%
np.isnan(label).any()
# Out:
# False

# %%
label = label.fillna(label.mean())

# %%
regression.fit(X, label)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-117-3a64ef887183> in <module>()
# ----> 1 regression.fit(X, label)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...

# %%
X
# Out:
# 0         2763.2
# 1         2763.2
# 2         2763.2
# 3         2763.2
# 4         2763.2
# 5         2763.2
# 6         2763.2
# 7         2763.2
# 8         2763.2
# 9         2763.2
# 10        3080.9
# 11        3080.9
# 12        3080.9
# 13        3080.9
# 14        3080.9
# 15        3080.9
# 16        3080.9
# 17        3080.9
# 18        2620.2
# 19        2620.2
# 20        2620.2
# 21        2620.2
# 22        2620.2
# 23        2620.2
# 24        2620.2
# 25        2620.2
# 26        2620.2
# 27        2355.9
# 28        2355.9
# 29        2355.9
#            ...
# 212552    1261.4
# 212553    1261.4
# 212554    1261.4
# 212555    1261.4
# 212556    1261.4
# 212557    1261.4
# 212558    1261.4
# 212559    1261.4
# 212560    1261.4
# 212561    1261.4
# 212562    1261.4
# 212563    1261.4
# 212564    1261.4
# 212565    1261.4
# 212566    1261.4
# 212567    1261.4
# 212568    1261.4
# 212569    1261.4
# 212570    1261.4
# 212571    1261.4
# 212572    1261.4
# ...

# %%
label.shape
# Out:
# (212582,)

# %%
X.shape
# Out:
# (212582, 3)

# %%
regression.fit(X, label)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
X.head()
# Out:
#    state  year  ANNUAL
# 0     31  2000  2763.2
# 1     31  2000  2763.2
# 2     31  2000  2763.2
# 3     31  2000  2763.2
# 4     31  2000  2763.2

# %%
regression.predict([31, 2000, 2763.2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-66ef56475784> in <module>()
# ----> 1 regression.predict([31, 2000, 2763.2])
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/base.py in predict(self, X)
#     254             Returns predicted values.
#     255         """
# --> 256         return self._decision_function(X)
#     257
#     258     _preprocess_data = staticmethod(_preprocess_data)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/base.py in _decision_function(self, X)
#     237         check_is_fitted(self, "coef_")
#     238
# --> 239         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     240         return safe_sparse_dot(X, self.coef_.T,
#     241                                dense_output=True) + self.intercept_
#
# ...

# %%
X_train, X_test, Y_train, Y_test = sc.train_test_split(X, label, test_size = 0.5, random_state = 5)

# %%
import sklearn.cross_validation as sc

# %%
X_train.head()
# Out:
#         state  year  ANNUAL
# 186246      9  2014   701.2
# 50948      21  2005  1316.4
# 86492      33  2005  3031.1
# 183615      9  2009   610.2
# 38980      13  2003  1353.9

# %%
X_train.shape
# Out:
# (170065, 3)

# %%
Y_train.shape
# Out:
# (170065,)

# %%
reg = regression.fit(X_train, Y_train)

# %%
predictions = reg.predict(X_test)

# %%
predictions
# Out:
# array([ 55.61763521,  21.18374311,  58.29234162, ..., 100.41549784,
#         21.7311096 ,  91.30877104])

# %%
sklearn.metrics.r2_score(Y_test, predictions)
# Out:
# 0.0016850452330913201

# %%
new_frame = pd.DataFrame(zip(X.columns, regression.coef_), columns=['features', 'estimateCoeff'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-105-730d03def371> in <module>()
# ----> 1 new_frame = pd.DataFrame(zip(X.columns, regression.coef_), columns=['features', 'estimateCoeff'])
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     405                 mgr = self._init_dict({}, index, columns, dtype=dtype)
#     406         elif isinstance(data, collections.Iterator):
# --> 407             raise TypeError("data argument can't be an iterator")
#     408         else:
#     409             try:
#
# TypeError: data argument can't be an iterator
