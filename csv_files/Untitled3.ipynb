# %%
import pandas as pd

df = pd.read_csv('check.csv')
df.head()
# Out:
#    Unnamed: 0                        state  district  year       season  \
# 0           0  andaman and nicobar islands  NICOBARS  2000  Kharif
# 1           1  andaman and nicobar islands  NICOBARS  2000  Kharif
# 2           2  andaman and nicobar islands  NICOBARS  2000  Kharif
# 3           3  andaman and nicobar islands  NICOBARS  2000  Whole Year
# 4           4  andaman and nicobar islands  NICOBARS  2000  Whole Year
#
#                   crop    area  production    JAN   FEB         ...          \
# 0             Arecanut  1254.0       2000.0  53.0  59.0         ...
# 1  Other Kharif pulses     2.0          1.0  53.0  59.0         ...
# 2                 Rice   102.0        321.0  53.0  59.0         ...
# 3               Banana   176.0        641.0  53.0  59.0         ...
# 4            Cashewnut   720.0        165.0  53.0  59.0         ...
#
#      MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  \
# ...

# %%
data = df.groupby(['state', 'crop'], as_index=False)['production_by_area'].sum()
data.head()
# Out:
#                          state          crop  production_by_area
# 0  andaman and nicobar islands      Arecanut           24.435546
# 1  andaman and nicobar islands     Arhar/Tur            0.952222
# 2  andaman and nicobar islands        Banana          142.375212
# 3  andaman and nicobar islands  Black pepper            3.132999
# 4  andaman and nicobar islands     Cashewnut            6.587932

# %%
for obj in df:
    print(obj)
# Out:
# Unnamed: 0
# state
# district
# year
# season
# crop
# area
# production
# JAN
# FEB
# MAR
# APR
# MAY
# JUN
# JUL
# AUG
# SEP
# OCT
# NOV
# DEC
# ANNUAL
# production_by_area

# %%
data = df.loc[df['state'] == 'west bengal']

# %%
data = data.groupby('crop', as_index=False)['production_by_area'].sum()
data
# Out:
#                      crop  production_by_area
# 0                Arecanut          291.038994
# 1               Arhar/Tur          157.491157
# 2                   Bajra           20.358990
# 3                  Barley          130.036991
# 4                Cardamom            4.342060
# 5             Castor seed           11.120359
# 6                Coconut        463090.100646
# 7            Cotton(lint)          149.041843
# 8            Dry chillies          194.948224
# 9              Dry ginger          270.661374
# 10                 Garlic          189.681858
# 11                   Gram          185.459872
# 12              Groundnut          718.333529
# 13             Horse-gram           78.137350
# 14                  Jowar           30.530552
# 15                   Jute         3817.468230
# 16                Khesari          220.316159
# 17                Linseed           66.527971
# 18                  Maize         1177.390425
# ...

# %%
# crops = data['crop']
# prod = data['production_by_area']
# production = []
# for c in prod:
#     production.append(c)
# production
data
# Out:
#                      crop  production_by_area
# 0                Arecanut          291.038994
# 1               Arhar/Tur          157.491157
# 2                   Bajra           20.358990
# 3                  Barley          130.036991
# 4                Cardamom            4.342060
# 5             Castor seed           11.120359
# 6                Coconut        463090.100646
# 7            Cotton(lint)          149.041843
# 8            Dry chillies          194.948224
# 9              Dry ginger          270.661374
# 10                 Garlic          189.681858
# 11                   Gram          185.459872
# 12              Groundnut          718.333529
# 13             Horse-gram           78.137350
# 14                  Jowar           30.530552
# 15                   Jute         3817.468230
# 16                Khesari          220.316159
# 17                Linseed           66.527971
# 18                  Maize         1177.390425
# ...

# %%
data = data.loc[data['state'] == 'west bengal']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'state'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-101-c63e0e72dd5c> in <module>()
# ...

# %%
data = data.sort_values('production_by_area', ascending=False)
data = data.head()
data
# Out:
#          crop  production_by_area
# 6    Coconut        463090.100646
# 36  Sugarcane        19467.730767
# 27     Potato         6366.722767
# 15       Jute         3817.468230
# 30       Rice         1992.682301

# %%
data
crop = []
prod = []
for obj in data['crop']:
    crop.append(obj)
for obj in data['production_by_area']:
    prod.append(obj)

print(crop, prod)
# Out:
# ['Coconut ', 'Sugarcane', 'Potato', 'Jute', 'Rice'] [463090.1006461934, 19467.730766625496, 6366.722767123638, 3817.468229998741, 1992.6823014744712]

# %%
df = pd.DataFrame({'production' : prod}, index = crop)

# %%
plot = df.plot.pie(y='production', figsize=(10,10))
