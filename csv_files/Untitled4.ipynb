# %%
import pandas as pd
data = pd.read_csv('check.csv')
data.head()
# Out:
#    Unnamed: 0                        state  district  year       season  \
# 0           0  andaman and nicobar islands  NICOBARS  2000  Kharif
# 1           1  andaman and nicobar islands  NICOBARS  2000  Kharif
# 2           2  andaman and nicobar islands  NICOBARS  2000  Kharif
# 3           3  andaman and nicobar islands  NICOBARS  2000  Whole Year
# 4           4  andaman and nicobar islands  NICOBARS  2000  Whole Year
#
#                   crop    area  production    JAN   FEB         ...          \
# 0             Arecanut  1254.0       2000.0  53.0  59.0         ...
# 1  Other Kharif pulses     2.0          1.0  53.0  59.0         ...
# 2                 Rice   102.0        321.0  53.0  59.0         ...
# 3               Banana   176.0        641.0  53.0  59.0         ...
# 4            Cashewnut   720.0        165.0  53.0  59.0         ...
#
#      MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  \
# ...

# %%
data = data.groupby(['state', 'crop'], as_index=False)['production'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-3044421bf2b8> in <module>()
# ----> 1 data = data.groupby(['state', 'crop'], as_index=False)['production'].sum()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6657         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6658                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6659                        observed=observed, **kwargs)
#    6660
#    6661     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2150         raise TypeError('invalid type: %s' % type(obj))
#    2151
# -> 2152     return klass(obj, by, **kwds)
# ...

# %%
data.head()
# Out:
#                          state          crop  production_by_area
# 0  andaman and nicobar islands      Arecanut           24.435546
# 1  andaman and nicobar islands     Arhar/Tur            0.952222
# 2  andaman and nicobar islands        Banana          142.375212
# 3  andaman and nicobar islands  Black pepper            3.132999
# 4  andaman and nicobar islands     Cashewnut            6.587932

# %%
data = data.loc[data['state'] == 'uttar pradesh']
data.head()
# Out:
#               state         crop  production_by_area
# 1100  uttar pradesh    Arhar/Tur          764.240648
# 1101  uttar pradesh        Bajra         1340.121947
# 1102  uttar pradesh       Banana        11033.870171
# 1103  uttar pradesh       Barley         2332.980134
# 1104  uttar pradesh  Castor seed            4.200000

# %%
data = data.groupby('crop', as_index=False)['production_by_area'].sum()

# %%
data
# Out:
#                      crop  production_by_area
# 0               Arhar/Tur          764.240648
# 1                   Bajra         1340.121947
# 2                  Banana        11033.870171
# 3                  Barley         2332.980134
# 4             Castor seed            4.200000
# 5               Coriander          314.861373
# 6            Cotton(lint)           96.772537
# 7            Dry chillies          658.639957
# 8              Dry ginger          304.978244
# 9                  Garlic         2848.113120
# 10                 Ginger           27.631490
# 11                   Gram          984.243582
# 12              Groundnut          669.041631
# 13              Guar seed          540.025386
# 14                  Jowar          936.258709
# 15                   Jute            3.502976
# 16                Linseed          279.735533
# 17                  Maize         3702.595284
# 18                 Masoor          758.072841
# ...

# %%
data = data.head()
crop = []
prod = []
for obj in data['crop']:
    crop.append(obj)
for obj in data['production_by_area']:
    prod.append(obj)

# %%
df = pd.DataFrame({'production' : prod}, index = crop)

# %%
plot = df.plot.pie(y='production', figsize=(5,5))

# %%
plot
