# %%
import pandas as pd
data = pd.read_csv('check.csv')

# %%
data.head()
# Out:
#    Unnamed: 0                        state  district  year       season  \
# 0           0  andaman and nicobar islands  NICOBARS  2000  Kharif
# 1           1  andaman and nicobar islands  NICOBARS  2000  Kharif
# 2           2  andaman and nicobar islands  NICOBARS  2000  Kharif
# 3           3  andaman and nicobar islands  NICOBARS  2000  Whole Year
# 4           4  andaman and nicobar islands  NICOBARS  2000  Whole Year
#
#                   crop    area  production    JAN   FEB         ...          \
# 0             Arecanut  1254.0       2000.0  53.0  59.0         ...
# 1  Other Kharif pulses     2.0          1.0  53.0  59.0         ...
# 2                 Rice   102.0        321.0  53.0  59.0         ...
# 3               Banana   176.0        641.0  53.0  59.0         ...
# 4            Cashewnut   720.0        165.0  53.0  59.0         ...
#
#      MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  \
# ...

# %%
data.head()
# Out:
#    Unnamed: 0                        state  district  year       season  \
# 0           0  andaman and nicobar islands  NICOBARS  2000  Kharif
# 1           1  andaman and nicobar islands  NICOBARS  2000  Kharif
# 2           2  andaman and nicobar islands  NICOBARS  2000  Kharif
# 3           3  andaman and nicobar islands  NICOBARS  2000  Whole Year
# 4           4  andaman and nicobar islands  NICOBARS  2000  Whole Year
#
#                   crop    area  production    JAN   FEB         ...          \
# 0             Arecanut  1254.0       2000.0  53.0  59.0         ...
# 1  Other Kharif pulses     2.0          1.0  53.0  59.0         ...
# 2                 Rice   102.0        321.0  53.0  59.0         ...
# 3               Banana   176.0        641.0  53.0  59.0         ...
# 4            Cashewnut   720.0        165.0  53.0  59.0         ...
#
#      MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  \
# ...

# %%
data = data.groupby(['state', 'crop', 'year'], as_index=False)['production '].sum()

# %%
data['year'].dtype
# Out:
# dtype('int64')

# %%
data = data.loc[(data['state'] == 'uttar pradesh') & (data['year'] == 2012)]
data.head()
# Out:
#               state       crop  year  production
# 9841  uttar pradesh  Arhar/Tur  2012     324649.0
# 9856  uttar pradesh      Bajra  2012    1757776.0
# 9865  uttar pradesh     Banana  2012     105337.0
# 9880  uttar pradesh     Barley  2012     445657.0
# 9890  uttar pradesh  Coriander  2012       3613.0

# %%
data = data.sort_values('production ' , ascending = False)

# %%
data.head()
# Out:
#                state       crop  year  production
# 10194  uttar pradesh  Sugarcane  2012  137904315.0
# 10274  uttar pradesh      Wheat  2012   31332434.0
# 10122  uttar pradesh       Rice  2012   14415939.0
# 10090  uttar pradesh     Potato  2012   13336619.0
# 9856   uttar pradesh      Bajra  2012    1757776.0

# %%
data = data.groupby(['crop', 'year'], as_index=False)['production '].sum()

# %%
data.head()
# Out:
#          crop  year  production
# 26  Sugarcane  2012  137904315.0
# 32      Wheat  2012   31332434.0
# 21       Rice  2012   14415939.0
# 19     Potato  2012   13336619.0
# 1       Bajra  2012    1757776.0

# %%
data.sort_values('production ', ascending=False)
data
# Out:
#          crop  year  production
# 26  Sugarcane  2012  137904315.0
# 32      Wheat  2012   31332434.0
# 21       Rice  2012   14415939.0
# 19     Potato  2012   13336619.0
# 1       Bajra  2012    1757776.0

# %%
crop = []
prod = []
for obj in data['crop']:
    crop.append(obj)
for obj in data['production ']:
    prod.append(obj)

# %%
data = data.sort_values('production ', ascending=False)
data
data = data.head()

# %%
data
# Out:
#          crop  year  production
# 26  Sugarcane  2012  137904315.0
# 32      Wheat  2012   31332434.0
# 21       Rice  2012   14415939.0
# 19     Potato  2012   13336619.0
# 1       Bajra  2012    1757776.0

# %%
df = pd.DataFrame({'production' : prod}, index = crop)
plot = df.plot.pie(y='production', figsize=(10, 10))

# %%
data['year'].dtype
# Out:
# dtype('int64')
