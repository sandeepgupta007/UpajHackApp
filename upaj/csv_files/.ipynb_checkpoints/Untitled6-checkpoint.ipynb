# %%
import pandas as pd
data = pd.read_csv('rainfall_data.csv')
data.head()
# Out:
#                    SUBDIVISION  YEAR   JAN   FEB    MAR    APR    MAY    JUN  \
# 0  andaman and nicobar islands  2000  53.0  59.0  171.3  218.1  422.8  357.0
# 1  andaman and nicobar islands  2001  89.0  15.7  143.3   30.1  705.3  370.7
# 2  andaman and nicobar islands  2002  10.6   0.0   11.5  100.2  366.7  358.3
# 3  andaman and nicobar islands  2003  44.3   7.9  149.2   19.4  296.3  159.9
# 4  andaman and nicobar islands  2004  54.5  35.9   36.5   41.6  505.1  423.9
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL
# 0  176.3  460.8  250.1  321.2  158.3  115.2  2763.2
# 1  341.3  469.0  334.4  267.6  222.6   91.8  3080.9
# 2  317.4  429.8  420.0  169.0  306.7  129.9  2620.2
# 3  494.9  379.4  371.9  310.4   74.1   48.0  2355.9
# 4  378.9  308.7  280.7  223.9  169.9    0.4  2460.1

# %%
data = data.groupby(['SUBDIVISION', 'YEAR'], as_index= False)
data.head()
# Out:
#                      SUBDIVISION  YEAR    JAN    FEB    MAR    APR    MAY  \
# 0    andaman and nicobar islands  2000   53.0   59.0  171.3  218.1  422.8
# 1    andaman and nicobar islands  2001   89.0   15.7  143.3   30.1  705.3
# 2    andaman and nicobar islands  2002   10.6    0.0   11.5  100.2  366.7
# 3    andaman and nicobar islands  2003   44.3    7.9  149.2   19.4  296.3
# 4    andaman and nicobar islands  2004   54.5   35.9   36.5   41.6  505.1
# 5    andaman and nicobar islands  2005    0.0    0.0   20.3   51.1  305.3
# 6    andaman and nicobar islands  2006   16.3   14.4   48.9  163.7  321.4
# 7    andaman and nicobar islands  2007    4.9    1.6    5.0   54.6  370.0
# 8    andaman and nicobar islands  2008    9.9   67.7  115.8  216.1  545.5
# 9    andaman and nicobar islands  2009   24.5    6.3   44.2  136.5  313.1
# 10   andaman and nicobar islands  2010  101.7    8.0    0.7   12.5  319.0
# 11   andaman and nicobar islands  2011  265.9   84.8  272.8  111.4  326.5
# ...

# %%
year = []
for obj in data['YEAR']:
    year.append(obj)
print(year)
