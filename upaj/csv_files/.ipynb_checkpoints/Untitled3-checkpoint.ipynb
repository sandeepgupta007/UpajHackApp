# %%
import pandas as pd
df = pd.read_csv('check.csv')
df.head()
# Out:
#    Unnamed: 0                        state  district  year       season  \
# 0           0  andaman and nicobar islands  NICOBARS  2000  Kharif
# 1           1  andaman and nicobar islands  NICOBARS  2000  Kharif
# 2           2  andaman and nicobar islands  NICOBARS  2000  Kharif
# 3           3  andaman and nicobar islands  NICOBARS  2000  Whole Year
# 4           4  andaman and nicobar islands  NICOBARS  2000  Whole Year
#
#                   crop    area  production    JAN   FEB         ...          \
# 0             Arecanut  1254.0       2000.0  53.0  59.0         ...
# 1  Other Kharif pulses     2.0          1.0  53.0  59.0         ...
# 2                 Rice   102.0        321.0  53.0  59.0         ...
# 3               Banana   176.0        641.0  53.0  59.0         ...
# 4            Cashewnut   720.0        165.0  53.0  59.0         ...
#
#      MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  \
# ...

# %%
data = df.groupby(['state', 'crop'], as_index=False)['production_by_area'].sum()
data.head()
# Out:
#                          state          crop  production_by_area
# 0  andaman and nicobar islands      Arecanut           24.435546
# 1  andaman and nicobar islands     Arhar/Tur            0.952222
# 2  andaman and nicobar islands        Banana          142.375212
# 3  andaman and nicobar islands  Black pepper            3.132999
# 4  andaman and nicobar islands     Cashewnut            6.587932

# %%
for obj in df:
    print(obj)
# Out:
# Unnamed: 0
# state
# district
# year
# season
# crop
# area
# production
# JAN
# FEB
# MAR
# APR
# MAY
# JUN
# JUL
# AUG
# SEP
# OCT
# NOV
# DEC
# ANNUAL
# production_by_area

# %%
data = df.loc[df['state'] == 'andaman and nicobar islands']

# %%
data
# Out:
#                           state                 crop  production_by_area
# 0   andaman and nicobar islands             Arecanut           24.435546
# 1   andaman and nicobar islands            Arhar/Tur            0.952222
# 2   andaman and nicobar islands               Banana          142.375212
# 3   andaman and nicobar islands         Black pepper            3.132999
# 4   andaman and nicobar islands            Cashewnut            6.587932
# 5   andaman and nicobar islands             Coconut         68328.281099
# 6   andaman and nicobar islands         Dry chillies           22.362292
# 7   andaman and nicobar islands           Dry ginger           80.758810
# 8   andaman and nicobar islands            Groundnut            1.921902
# 9   andaman and nicobar islands                Maize            9.322425
# 10  andaman and nicobar islands    Moong(Green Gram)            1.806577
# 11  andaman and nicobar islands  Other Kharif pulses            2.146735
# ...

# %%
crops = data['crop']
prod = data['production_by_area']
print(crops, prod)
# Out:
# ['Arecanut', 'Arhar/Tur', 'Banana', 'Black pepper', 'Cashewnut', 'Coconut ', 'Dry chillies', 'Dry ginger', 'Groundnut', 'Maize', 'Moong(Green Gram)', 'Other Kharif pulses', 'Rice', 'Sugarcane', 'Sunflower', 'Sweet potato', 'Tapioca', 'Turmeric', 'Urad', 'other oilseeds']

# %%
data = data.loc[data['state'] == 'andaman and nicobar islands']

# %%
df = pd.DataFrame({'production' : crops}, index = prod)

# %%
df
# Out:
#                    production
# production_by_area
# 24.435546                 NaN
# 0.952222                  NaN
# 142.375212                NaN
# 3.132999                  NaN
# 6.587932                  NaN
# 68328.281099              NaN
# 22.362292                 NaN
# 80.758810                 NaN
# 1.921902                  NaN
# 9.322425                  NaN
# 1.806577                  NaN
# 2.146735                  NaN
# 49.381359                 NaN
# 201.133343                NaN
# 1.155172                  NaN
# 63.383982                 NaN
# 66.809335                 NaN
# 42.699989                 NaN
# 1.649005                  NaN
# 3.885539                  NaN

# %%
plot = df.plot.pie(y='production')
