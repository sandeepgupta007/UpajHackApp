# %%
import pandas as pd
data = pd.read_csv('check.csv')

# %%
data.head()
# Out:
#    Unnamed: 0                        state  district  year       season  \
# 0           0  andaman and nicobar islands  NICOBARS  2000  Kharif
# 1           1  andaman and nicobar islands  NICOBARS  2000  Kharif
# 2           2  andaman and nicobar islands  NICOBARS  2000  Kharif
# 3           3  andaman and nicobar islands  NICOBARS  2000  Whole Year
# 4           4  andaman and nicobar islands  NICOBARS  2000  Whole Year
#
#                   crop    area  production    JAN   FEB         ...          \
# 0             Arecanut  1254.0       2000.0  53.0  59.0         ...
# 1  Other Kharif pulses     2.0          1.0  53.0  59.0         ...
# 2                 Rice   102.0        321.0  53.0  59.0         ...
# 3               Banana   176.0        641.0  53.0  59.0         ...
# 4            Cashewnut   720.0        165.0  53.0  59.0         ...
#
#      MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  \
# 0  422.8  357.0  176.3  460.8  250.1  321.2  158.3  115.2  2763.2
# 1  422.8  357.0  176.3  460.8  250.1  321.2  158.3  115.2  2763.2
# 2  422.8  357.0  176.3  460.8  250.1  321.2  158.3  115.2  2763.2
# 3  422.8  357.0  176.3  460.8  250.1  321.2  158.3  115.2  2763.2
# 4  422.8  357.0  176.3  460.8  250.1  321.2  158.3  115.2  2763.2
#
#    production_by_area
# 0            1.594896
# 1            0.500000
# 2            3.147059
# 3            3.642045
# 4            0.229167
#
# [5 rows x 22 columns]

# %%
data.head()
# Out:
#    Unnamed: 0                        state  district  year       season  \
# 0           0  andaman and nicobar islands  NICOBARS  2000  Kharif
# 1           1  andaman and nicobar islands  NICOBARS  2000  Kharif
# 2           2  andaman and nicobar islands  NICOBARS  2000  Kharif
# 3           3  andaman and nicobar islands  NICOBARS  2000  Whole Year
# 4           4  andaman and nicobar islands  NICOBARS  2000  Whole Year
#
#                   crop    area  production    JAN   FEB         ...          \
# 0             Arecanut  1254.0       2000.0  53.0  59.0         ...
# 1  Other Kharif pulses     2.0          1.0  53.0  59.0         ...
# 2                 Rice   102.0        321.0  53.0  59.0         ...
# 3               Banana   176.0        641.0  53.0  59.0         ...
# 4            Cashewnut   720.0        165.0  53.0  59.0         ...
#
#      MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  \
# 0  422.8  357.0  176.3  460.8  250.1  321.2  158.3  115.2  2763.2
# 1  422.8  357.0  176.3  460.8  250.1  321.2  158.3  115.2  2763.2
# 2  422.8  357.0  176.3  460.8  250.1  321.2  158.3  115.2  2763.2
# 3  422.8  357.0  176.3  460.8  250.1  321.2  158.3  115.2  2763.2
# 4  422.8  357.0  176.3  460.8  250.1  321.2  158.3  115.2  2763.2
#
#    production_by_area
# 0            1.594896
# 1            0.500000
# 2            3.147059
# 3            3.642045
# 4            0.229167
#
# [5 rows x 22 columns]

# %%
data = data.groupby(['state', 'crop'], as_index=False)['production '].sum()

# %%
data.head()
# Out:
#                          state          crop  production
# 0  andaman and nicobar islands      Arecanut     48035.81
# 1  andaman and nicobar islands     Arhar/Tur       104.00
# 2  andaman and nicobar islands        Banana     97424.65
# 3  andaman and nicobar islands  Black pepper       724.50
# 4  andaman and nicobar islands     Cashewnut      1684.79

# %%
data = data.loc[data['state'] == 'uttar pradesh']
data.head()
# Out:
#               state         crop  production
# 1100  uttar pradesh    Arhar/Tur    3895599.0
# 1101  uttar pradesh        Bajra   21024276.0
# 1102  uttar pradesh       Banana     809492.0
# 1103  uttar pradesh       Barley    6538603.0
# 1104  uttar pradesh  Castor seed         16.2

# %%
data = data.sort_values('production ' , ascending = False)

# %%
data.head()
# Out:
#               state       crop   production
# 1133  uttar pradesh  Sugarcane  1.870482e+09
# 1139  uttar pradesh      Wheat  3.997329e+08
# 1128  uttar pradesh       Rice  1.836561e+08
# 1125  uttar pradesh     Potato  1.673671e+08
# 1101  uttar pradesh      Bajra  2.102428e+07

# %%
data = data.groupby('crop', as_index=False)['production '].sum()

# %%
data.head()
# Out:
#           crop  production
# 0    Arhar/Tur    3895599.0
# 1        Bajra   21024276.0
# 2       Banana     809492.0
# 3       Barley    6538603.0
# 4  Castor seed         16.2

# %%
data.sort_values('production ', ascending=False)
data
# Out:
#                      crop   production
# 0               Arhar/Tur  3.895599e+06
# 1                   Bajra  2.102428e+07
# 2                  Banana  8.094920e+05
# 3                  Barley  6.538603e+06
# 4             Castor seed  1.620000e+01
# 5               Coriander  3.059200e+04
# 6            Cotton(lint)  2.400600e+04
# 7            Dry chillies  1.443250e+05
# 8              Dry ginger  2.461100e+04
# 9                  Garlic  1.574042e+06
# 10                 Ginger  4.354000e+03
# 11                   Gram  8.661104e+06
# 12              Groundnut  1.076807e+06
# 13              Guar seed  2.181800e+04
# 14                  Jowar  3.452429e+06
# 15                   Jute  2.500000e+01
# 16                Linseed  2.186970e+05
# 17                  Maize  1.848776e+07
# 18                 Masoor  5.492699e+06
# 19      Moong(Green Gram)  4.485508e+05
# 20                   Moth  4.305000e+02
# 21                  Onion  3.764392e+06
# 22     Other  Rabi pulses  7.059650e+05
# 23    Other Kharif pulses  3.300900e+05
# 24  Peas & beans (Pulses)  4.474454e+06
# 25                 Potato  1.673671e+08
# 26                   Ragi  1.187000e+03
# 27      Rapeseed &Mustard  9.619186e+06
# 28                   Rice  1.836561e+08
# 29               Sannhamp  1.092400e+04
# 30                Sesamum  5.319317e+05
# 31          Small millets  1.394701e+05
# 32               Soyabean  1.645840e+05
# 33              Sugarcane  1.870482e+09
# 34              Sunflower  1.861680e+05
# 35           Sweet potato  2.556292e+06
# 36                Tobacco  1.876355e+06
# 37               Turmeric  5.336500e+04
# 38                   Urad  2.997478e+06
# 39                  Wheat  3.997329e+08

# %%
crop = []
prod = []
for obj in data['crop']:
    crop.append(obj)
for obj in data['production ']:
    prod.append(obj)

# %%
data = data.sort_values('production ', ascending=False)
data.head()
data = data.head()

# %%
data
# Out:
#          crop   production
# 33  Sugarcane  1.870482e+09
# 39      Wheat  3.997329e+08
# 28       Rice  1.836561e+08
# 25     Potato  1.673671e+08
# 1       Bajra  2.102428e+07

# %%
df = pd.DataFrame({'production' : prod}, index = crop)
plot = df.plot.pie(y='production', figsize=(10, 10))
